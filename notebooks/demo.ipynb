# %% [markdown]
# ### Clone the library

# %%
# !git clone https://github.com/ARBML/klaam
# %cd klaam

# %% [markdown]
# ### Install dependencies

# %%
# %%capture
# !pip install -r requirements.txt

# %% [markdown]
# ### Load sample audio file

# %%
from IPython.display import Audio 
Audio('../samples/demo.wav', autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ### Classification model

# %%
from klaam import SpeechClassification
model = SpeechClassification()
model.classify('../samples/demo.wav')
# Out:
# /home/alotaima/miniconda3/envs/klaam_test/lib/python3.7/site-packages/transformers/configuration_utils.py:359: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   "Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 "
# 'EGY'

# %% [markdown]
# ### Recongition model

# %%
from klaam import SpeechRecognition
model = SpeechRecognition()
model.transcribe('../samples/demo.wav')
# Out:
# /home/alotaima/miniconda3/envs/klaam_test/lib/python3.7/site-packages/transformers/configuration_utils.py:359: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   "Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 "
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# 'أكل بتاعهو بيبقى مميز قوي عرفة إزاي ف والل ه إحنا كلنا كل يوم بنعمل حيلة عشان نسهب الشنطة بتاعته ناخد الأكن ورجع أ'

# %% [markdown]
# ### Text to Speech

# %%
from klaam import TextToSpeech
from IPython.display import Audio

root_path = "../"
prepare_tts_model_path = "../cfgs/FastSpeech2/config/Arabic/preprocess.yaml"
model_config_path = "../cfgs/FastSpeech2/config/Arabic/model.yaml"
train_config_path = "../cfgs/FastSpeech2/config/Arabic/train.yaml"
vocoder_config_path = "../cfgs/FastSpeech2/model_config/hifigan/config.json"
speaker_pre_trained_path = "../data/model_weights/hifigan/generator_universal.pth.tar"

model = TextToSpeech(prepare_tts_model_path, model_config_path, train_config_path, vocoder_config_path, speaker_pre_trained_path,root_path)

model.synthesize("وَسادْيُو مَانِي فِي الدَّقِيقَتَيْنِ السّابِعَةَ عَشْرَةَ - وَ الْخَامِسَةَ وَالْأَرْبعينَ مِنَ الشَّوْطِ الْأَوَّلِ لِلْمُبَارَاةِ")
Audio("sample.wav")
# Out:
# Removing weight norm...
# Raw Text Sequence: وَسادْيُو مَانِي فِي الدَّقِيقَتَيْنِ السّابِعَةَ عَشْرَةَ - وَ الْخَامِسَةَ وَالْأَرْبعينَ مِنَ الشَّوْطِ الْأَوَّلِ لِلْمُبَارَاةِ
# Phoneme Sequence: {w a s aa d y uu0 m aa n ii0 f ii0 dd A q II0 q A t a y n i0 ss aa b i0 E a t a E a $ r a t a sil w a l x AA m i0 s a t a w a l < a r b E ii0 n a m i0 n a $$ a w T I0 l < a ww a l i0 l i0 l m u0 b aa r aa t i0 sil}
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
